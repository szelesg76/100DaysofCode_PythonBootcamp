# %% [markdown]
# Teszteredmények:

# %%
def add_new(a:int) -> int:
    return a + 13

# %%
a = 1 + 2

# %%
print(add_new(a))
# Out:
# 16

# %%
def add_new(a:int) -> int:
    return a + 21

# %%
print(add_new(a))
# Out:
# 24
